# %%
# import libraries
import pandas as pd
import numpy as np
import glob, os

# %%
# download data
hip=pd.read_csv('data/hipsci_files.tsv',sep='\t',index_col=0) # hipsci_files.tsv file is exported from https://www.hipsci.org/lines/#/lines 
ftps=hip['FTP url'].values
#for ftp in ftps: # uncomment this to download the count files
#    !wget -nc -P ../data/tpm {ftp+'*.tsv'}

# %%
# compine them into a list of list
ips=[]
cells=[]
for file in glob.glob("../data/tpm/*.tsv"):
    cells.append(file.split('.GRCh37.')[0].split('tpm/')[1])
    ip=pd.read_csv(file,sep='\t',index_col=0)[['tpm']].round(2)  
    ip=ip.tpm.values
    ips.append(ip)
ind=pd.read_csv(file,sep='\t',index_col=0).index

# %%
# convert it into pandas
df=pd.DataFrame(ips)
df.columns=ind
df.index=cells
df=df.T
df.shape
# Out:
# (179659, 330)

# %%
#get ENS to Gene mapping data and mapp
ens=pd.read_csv('../data/mart_export.txt.gz',sep='\t',index_col=1)
ens=ens.rename(columns={'Gene name':'gene','Gene stable ID':'id'})
print(ens.shape)
df=df.merge(ens[['gene']],left_index=True,right_index=True)
# Out:
# (215170, 2)

# %%
#aggregate transcripts to get gene level data and write it into a combined table
dg=df.groupby('gene').sum()
dg.T.to_csv('../data/ips_tpm.gz', compression='gzip')

# %%
#top few rows
dg.head()
# Out:
#        HPSI1213i-xuja_2  HPSI0614i-voce_2  HPSI0814i-doao_2  HPSI0314i-sojd_3  \
# gene
# A1BG              21.10              7.71             19.51             17.89
# A1CF               0.05              0.03              0.11              0.02
# A2M                2.35              1.47              1.27              0.90
# A2ML1              1.59              4.97              2.48              3.83
# A2MP1              0.57              0.17              0.41              0.16
#
#        HPSI0114i-lexy_2  HPSI1013i-jufd_2  HPSI0215i-deyz_3  HPSI0514i-sohd_2  \
# gene
# A1BG              14.99             15.65             19.42             13.19
# A1CF               0.01              0.04              0.09              0.07
# A2M                0.33              0.51              0.88              1.70
# A2ML1              1.30              3.47              3.07              2.95
# A2MP1              0.05              0.18              0.15              0.26
#
#        HPSI0714i-kute_4  HPSI0115i-payf_1  ...  HPSI0214i-kucg_2  \
# gene                                       ...
# A1BG              15.50             15.96  ...             20.23
# A1CF               0.01              0.04  ...              0.04
# A2M                2.31              0.95  ...              2.68
# A2ML1              3.70              1.70  ...              3.22
# A2MP1              0.22              0.24  ...              0.30
#
#        HPSI0114i-iisa_3  HPSI0114i-vabj_3  HPSI0115i-sehp_3  HPSI0314i-qonc_2  \
# gene
# A1BG              18.90             25.67             31.10             23.66
# A1CF               0.17              0.06              0.04              0.11
# A2M                0.32              0.97              0.70              1.37
# A2ML1              2.17              3.55              1.43              3.38
# A2MP1              0.18              0.12              0.17              0.27
#
#        HPSI0214i-datg_2  HPSI0114i-kolf_3  HPSI0115i-vazt_2  HPSI0114i-iisa_1  \
# gene
# A1BG              22.48             22.97             13.43             21.35
# A1CF               0.04              0.06              0.10              0.07
# A2M                1.46              1.29              1.66              0.24
# A2ML1              2.80              2.08              2.97              2.03
# A2MP1              0.16              0.23              0.18              0.20
#
#        HPSI0714i-nufh_3
# gene
# A1BG              13.07
# A1CF               0.09
# A2M                0.23
# A2ML1              5.43
# A2MP1              0.08
#
# [5 rows x 330 columns]
