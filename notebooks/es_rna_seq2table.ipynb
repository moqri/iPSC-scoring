# %%
data='../data/'
esc='https://ftp.ncbi.nlm.nih.gov/geo/series/GSE73nnn/GSE73211/suppl/GSE73211_nonisogenic.TPM.txt.gz'
esc2='https://ftp.ncbi.nlm.nih.gov/geo/series/GSE73nnn/GSE73211/suppl/GSE73211_isogenic.TPM.txt.gz'

# %%
import pandas as pd
import ssl
ssl._create_default_https_context = ssl._create_unverified_context

# %%
df=pd.read_csv(esc,sep='\t',header=None,skiprows=1,index_col=0)
columns=pd.read_csv(esc,nrows=0,sep=' ').columns
columns=columns.str.replace("ID\t",'')
df.columns=columns

# %%
df=df[[c for c in df.columns if 'iPS' not in c]]
df.shape
# Out:
# (49878, 18)

# %%
df2=pd.read_csv(esc2,sep='\t',header=None,skiprows=1,index_col=0)
columns=pd.read_table(esc2,nrows=0).columns
columns=columns.str.replace("ID\t",'')
df2.columns=columns
df2=df2[[c for c in df2.columns if 'hESC' in c and 'Fib' not in c ]]

# %%
df=df.merge(df2,left_index=True,right_index=True)
df.head()
# Out:
#                     HUES44       HUES13       HUES49           H9  \
# 0
# RP11-560A15.3     0.146946     0.000000     0.000000     0.000000
# CREB3L1           7.090249    12.874444     6.893560    14.299036
# RPS11          3308.598948  3219.722012  2819.413250  3234.018830
# RP11-783L4.1      0.000000     0.000000     0.191850     0.000000
# PNMA1            46.284430    51.292378    43.249625    45.620964
#
#                      HUES1       HUES45       HUES62           H1  \
# 0
# RP11-560A15.3     0.000000     0.000000     0.000000     0.000000
# CREB3L1           7.589362     6.421404     7.699287    18.053911
# RPS11          3052.887296  2872.764855  2573.431455  3157.636567
# RP11-783L4.1      0.000000     0.000000     0.000000     0.000000
# PNMA1            37.082920    45.402363    58.641040    34.874149
#
#                      HUES8       HUES66  ...   hESC SC2-3   hESC SC3-1  \
# 0                                        ...
# RP11-560A15.3     0.000000     0.000000  ...     0.000000     0.000000
# CREB3L1           9.808937     7.560934  ...    12.447480     6.886064
# RPS11          3092.851810  3210.420324  ...  3301.984295  2840.934509
# RP11-783L4.1      0.000000     0.000000  ...     0.280735     0.000000
# PNMA1            42.376571    54.397558  ...    34.163900    34.900165
#
#                 hESC SC3-2   hESC SC3-3   hESC GFP12   hESC GFP13  \
# 0
# RP11-560A15.3     0.000000     0.000000     0.000000     0.000000
# CREB3L1           5.653596     6.754446    11.012172     7.621126
# RPS11          2839.811164  2845.844446  3293.581132  3128.847523
# RP11-783L4.1      0.000000     0.000000     0.000000     0.000000
# PNMA1            29.989708    27.379224    39.504944    37.978849
#
#                  hESC GFP5    hESC GFP2    hESC GFP3   hESC GFP15
# 0
# RP11-560A15.3     0.000000     0.000000     0.000000     0.000000
# CREB3L1          11.815619     5.705730     6.752222     6.313430
# RPS11          3421.976296  3164.825934  3191.008986  3183.825373
# RP11-783L4.1      0.192976     0.000000     0.000000     0.000000
# PNMA1            42.192685    35.687738    38.812193    35.485875
#
# [5 rows x 30 columns]

# %%
df.astype(float).round(2).T.to_csv(data+'es_tpm.csv.gz', compression='gzip')
